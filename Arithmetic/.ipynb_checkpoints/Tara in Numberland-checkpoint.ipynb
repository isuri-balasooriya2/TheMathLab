# %% [markdown]
# # Basic Arithmetics
#
# Imagine a world where everything—patterns, nature, technology—can be explained through numbers. To navigate this world, we must first understand its language. We start at the very beginning: whole numbers, the first building blocks of mathematics, before venturing into the intricate web of real numbers, fractions, and beyond.

# %% [markdown]
# **Natural numbers** are numbers we use for counting. It doesnt include zero and negatives
#
# 1,2,3,4,5 ....

# %% [markdown]
# The place value of a number depends on its location.
#
# 5738
# 8 is in ones place so the value is 8
# 3 is in tens place so the value is 30
# 7 is in hundreds place so the value is 700
# 5 is in thousands place so the value is 5000

# %% [markdown]
# **Whole numbers** AKA **Integers** include numbers from negative, zero to positive. But it doesnt include fractions or decimals.

# %% [markdown]
# **Even Numbers** are numbers divisible by 2
# **Odd Numbers** are numbers that are not divisible by 2

# %% [markdown]
# ## Arithmetic Operations
#
# Lets look at the basic arithmetic operations.
# Addition
# Subtraction
# Multiplication
# Division

# %%
4+2
# Out:
# 6

# %%
4-2

# %%
4*2

# %%
4/2

# %% [markdown]
# The order of operations goes as (BODMAS) or (PEDMAS)
# That means
# 1. Brackets/ Paranthesis
# 2. Orders/ Exponents
# 3. Division
# 4. Multiplication
# 5. Addition
# 6. Subtraction

# %%
(8*5) - (12/4)
# Out:
# 37.0

# %% [markdown]
# ## Negative Numbers
#
# When muliplying/ Dividing negative numbers
# (-) * (-) always becomes +
# (-) * (+) always becomes -
#
# Adding a negative number is like moving right along the number line.

# %%
8 + -5
# Out:
# 3

# %% [markdown]
# Subtracting negative numbers is something I struggled to grasp initially.
#
# how does 3 - -5 becomes +8

# %%
8 - -5
# Out:
# 13

# %% [markdown]
# Subtracting a negative number is the same as adding its positive counterpart. Mathematically, this is based on the rule:
#
# $a−(−b)=a+b$
#
# A negative sign in front of a negative number cancels out.

# %% [markdown]
# Whenever I have trouble with this, I think of this example,
# If you owe someone 5 dollars (-5) and then that debt is removed (- -5), you actually gain 5 dollars back!

# %% [markdown]
# ![image.png](attachment:f5969c43-6659-4d41-84b8-c8db9e8fa5e5.png)

# %% [markdown]
# Now we know what the number line is. An **Absolute Value** is the distance from zero on the number line. This value is always positive.
#
# The notation is as follows,
# |-8| = 8
# |5|  = 5

# %% [markdown]
# ## Fractions
#
# Fractions are a part of a whole.
#
# **Rational Numbers** include integers and fractions.
#
# $1/2$
#
# 1 is the numerator
# 2 is the denominator
#
# Fraction to decimal - divide the numerator from the denominator
# Decimal to percentage - multiply by 100
# Percentage to Fraction - divide by 100

# %%
1/2
# Out:
# 0.5

# %%
0.5*100
# Out:
# 50.0

# %% [markdown]
# 50/100 = 1/2

# %% [markdown]
# ## Fractions Operations
#
# Adding/ Subtracting - the denominator needs to be the same to add fractions.

# %% [markdown]
# 1/4 + 1/2
#
# = 1+2/4
#
# = 3/4

# %% [markdown]
# Multliplication - Multiply numerator*numerator/ denominator*denominator
#
# 2/3 * 3/4
# = 6/12
# = 1/2

# %% [markdown]
# Division - Multiply by the reciprocal of the second fraction
# (2/3) ÷ (3/4) = (2/3) × (4/3) = 8/9

# %% [markdown]
# ## Rations and Proportions
#
# Rations compare 2 quantities. If there are 3 girls and 2 boys then the girls to boys ration is 3:2
#
# Proportion is the equation that shows two rations are equal.

# %% [markdown]
# **Prime Numbers** are only divisible by 1 and itself
# 2,3,5,7,9,11,13,17,19,23,29

# %% [markdown]
# **Factorization** means breaking down a number to its prime factors

# %% [markdown]
# This is all for basic arithmetics.
